# %% [markdown]
# # Get Accela access token

# %%
import requests
import pandas as pd

# %%
#Set body parameters to App and Accela information

data = {'client_id': '637695663724668394', #Application ID
        'client_secret': '342b6fc9f76f49db993230d55511097f', #Application Secret ID
        'grant_type': 'password', #Security type
        'username': 'NREBOVICH', #My username
        'password': '#Test12345', #My password
        'scope': 'parcels', #Scope of API Call
        'agency_name': 'UG', #Accela Agency Name
        'environment': 'TEST'} # Type of environment (PROD, TEST ect.)

#Use POST method for authentication URL, data = the parameters above
token_response = requests.post('https://auth.accela.com/oauth2/token', data = data) 

#Print status code of call (200 is good, all others are an error)
print("Status Code")
print(token_response.status_code)

#Print call return
print(token_response.text)
# Out:
# Status Code
# 200
# {"access_token":"-xxOQzUj1N2wS_nJnpQncuOpBxMELY1YLRiHgzLSXSH7d1tLE_4bw6pY68ZkePYPg9GLn1SgA3BiCqfJf-GC15czWQ_QefMGvKnqsotp0wiZTsk5-Ap87NO6kidc29W3XH4un3WBe8b3aIfFkPx_NIFvqZGzb2uxTjFUkXXEHzqD9bmJ1g0u1T8gh4pnBz4LDDEVpCmMdWth0-hHs7R6KFvz68oJJ3cpXboE44nmGf0Ov1QzJyCz7MTCxxekl_SlSIfL3Evtp_G6RORywiPK_dsce1gMraK8II5Hfm0i8s-7sEC3jflWxl1lYNzxSujy1zSCddIWKpY35z-wjTrIZuLzeWwtMVWblgQ2ix3jKKmkTHXCX4qe3OWiiB9bkAvdxVc7IHshzU_QuyTwt09YIg2","token_type":"bearer","expires_in":86399,"refresh_token":"t2Ea0OZM63rCuXf0JNCjlDQEMsGySpjqBKMEy_St4h97VQWJuqn8K9veDpQz-INTtpzFPRrFNFks30ngjJpgfaNz7sSTHQVBp-q1d4LbB2-Emsf06LjjOIUu8RQeW_jBxAoMxHJv3LXgzeXEk14LSoHWyFjIdswdpyopwKXTxuZb2l_H3bPigG-oPJA2T4Fp1zmsvh447H4KCE1VfBqlV94xkuVNii5D7j9j8W6Axr36suzp0SitSk-Uy14aBDYjW3lJGunSCqr_az1XOtUvc0mb_nOSe4n8rhxfBMZRX2fmk2YUM4_OJ9s8uj0o7ivrd4iE2pfUbknWjZmFPFq2Iv2KoNEv9t1JjGUpsEqh9zC9BxklcmslESv13tK2KacwH58SDcR1p5dK6cIdbBjK82HSkouYXBJpF250jHTRqpY1","scope":"records"}

# %%
#Split call return based on a single double quote (need to use \ for this). Select third element which is the token info.
token = token_response.text.split("\"")[3]
token
# Out:
# '-xxOQzUj1N2wS_nJnpQncuOpBxMELY1YLRiHgzLSXSH7d1tLE_4bw6pY68ZkePYPg9GLn1SgA3BiCqfJf-GC15czWQ_QefMGvKnqsotp0wiZTsk5-Ap87NO6kidc29W3XH4un3WBe8b3aIfFkPx_NIFvqZGzb2uxTjFUkXXEHzqD9bmJ1g0u1T8gh4pnBz4LDDEVpCmMdWth0-hHs7R6KFvz68oJJ3cpXboE44nmGf0Ov1QzJyCz7MTCxxekl_SlSIfL3Evtp_G6RORywiPK_dsce1gMraK8II5Hfm0i8s-7sEC3jflWxl1lYNzxSujy1zSCddIWKpY35z-wjTrIZuLzeWwtMVWblgQ2ix3jKKmkTHXCX4qe3OWiiB9bkAvdxVc7IHshzU_QuyTwt09YIg2'

# %% [markdown]
# # Call Accela API

# %%
#Set host equal to base url for Accela API
host = 'https://apis.accela.com'

#Set dataset equal to the type of data you want. In this case it is records.
dataset = 'v4/parcels?isPrimary=Y'

#Join host and dataset with \
base_url = '/'.join([host,dataset])

#Output of joined variables host and dataset
base_url
# Out:
# 'https://apis.accela.com/v4/parcels?isPrimary=Y'

# %%
#Set basic parameters for the call
parameters = {
        'grant_type': 'password', #Security type
        'client_id': '637695663724668394', #Application ID
        'client_secret': '342b6fc9f76f49db993230d55511097f', #Application Secret ID
        'username': 'NREBOVICH', #My username
        'password': '#Test12345', #My password
        'scope': 'parcels', #Scope of API Call
        'agency_name': 'UG', #Accela Agency Name
        'environment': 'TEST',
        'limit': '50'
    }

#Set header to the token that was called above
token_header = {
        'Authorization': token
    }


#Call api for data based on parameters and token header
response = requests.get(base_url,params = parameters, headers = token_header).json()

print(response['status'])
# Out:
# 200

# %%
df = pd.DataFrame(response["result"])
df
# Out:
#      page censusTract   tract mapNumber mapReferenceInfo  \
# 0    0789       44805  122307       G07              650
# 1    0054       44803  102305       A05              657
# 2    0714       44803  102305       A05              657
# 3    0437       44803  102305       A05              658
# 4    0692       44803  102304       A04              659
# 5    1608       44803  102304       A04              660
# 6    0363       44804  102303       A03              661
# 7    0363       44804  102303       A03              661
# 8    0699       44804  102303       A03              662
# 9               44804  102302       A02              663
# 10              44804  102302       A02              663
# 11
# 12   0260       44302               213              B34
# 13   0598       44302               213              B34
# 14   0125       44302               213              B34
# 15  14898       44302               213              B34
# 16   0593       44302               213              B34
# 17   0426       44302               213              B34
# 18   0395       44302               213              B34
# 19   0494       44302               213              B34
# 20  04889       44302               213              B34
# 21   0428       44302               213              B34
# 22   0720       44302               213              B34
# 23  01990       44302               213              B34
# 24  17744       44302               213              B34
# 25  17763       44302               213              B34
# 26   0365       44302               213              B34
# 27   0616       44302               213              B34
# 28  04569       44302               213              B34
# 29  10073       44302               213              B34
# 30  07646       44302               213              B34
# 31   0088       44302               213              B34
# 32  00882       44302               213              B34
# 33  13980       44302               213              B34
# 34  10868       44302               213              B34
# 35   0861       44302               213              B34
# 36   0382       44302               213              B34
# 37   0720       44302               213              B34
# 38   0144       44302               213              B34
# 39   0897       44302               213              B34
# 40   0816       44302               213              B34
# 41  08774       44302               213              B34
# 42  09750       44302               213              B34
# 43   0370       44302               213              B34
# 44   0163       44302               213              B34
# 45  07036       44302               213              B34
# 46  06717       44302               213              B34
# 47  17379       44302               213              B34
# 48   0676       44302               213              B34
# 49  07074       44302               213              B34
#
#                                      legalDescription   book parcelNumber  \
# 0   BEG 1708FT E OF NW COR;  S11W-698.39FT, E 1205...   2012       65001
# 1   58-6 BEG 646.21FT W OF SE COR OF SW1/4; W 410....   3357       65706
# 2                                                 NaN   3883       65707
# 3                                                 NaN   3962       65801
# 4                 162A E1/2 OF SW1/4 CONTG 11.5AC M/L   3685       65901
# 5   W1/2 LOT 3 SE1/4 LS N 40FT;  ALSO 9-10-23:  NW...   2017       66000
# 6                      158,159 W 6.7AC OF SW FRAC 1/4   2859       66100
# 7       158,159-1 E 6.5AC OF W 13.24AC OF SW FRAC 1/4   2859       66102
# 8         2,3 LOT 3, SE FRAC 1/4 W OF 107TH ST LS R/W   2334       66200
# 9   1 LOT 4, SW FRAC 1/4 S OF WOLCOTT DR & LOT 3, ...              66300
# 10  1-2 BEG 908FT E OF SW COR, N31W- 63.9FT, N19E-...              66301
# 11          PHANTOM PARCEL FOR ROW ADDRESS - NO VALUE              90000
# 12          S 135.5FT L1 W OF 59TH ST &  S 135.5FT L2   5667       000100
# 13  N 174.5FT L1 W OF 59TH ST LS 0.006AC M/L FOR R...   1685       000101
# 14               L3 TO L5 & L6 LS N 10FT OF W 53.86FT   5243       000105
# 15  L7, L8 & N 10FT OF W 53.86FT L6;  ALSO BEG NW ...  2013R       000106
# 16                                           W1/2 L10   4452       000108
# 17                                                 L9   4378       000109
# 18                                L11, L12 & E1/2 L10   5424       000110
# 19  N1/2 L13 TO L15, N1/2 L16 LS 0.0133AC M/L FOR R/W   3763       000112
# 20  S1/2 L13 TO L14, S1/2 L15 LS N 137.11FT OF E 6...  2020R       000113
# 21        S1/2 L16 & S1/2 OF E 65.17FT L15; LS S 15FT   5632       000114
# 22  N 174.5FT OF L1 E OF 59TH ST LS 0.048AC M/L FO...   5730       000115
# 23  B1 L1 TO L3 LS N 10FT, N1/2 L7 & VAC ST: BEG 1...  2018R       000200
# 24                                              B1 L4  2019R       000201
# 25                                              B1 L5   2019       000202
# 26                                      B1 N 150FT L6   5099       000203
# 27                            B1 S 50FT OF N 200FT L6   5741       000204
# 28                                      B1 S 100FT L6  2016R       000205
# 29                B1 S1/2 L7 LS E 10FT & L8 LS E 10FT  2016R       000206
# 30                                              B1 L9  2015R       000207
# 31                                             B1 L10   4952       000208
# 32                                             B1 L11  2015R       000209
# 33                                             B1 L12  2018R       000210
# 34                                             B1 L13  2013R       000211
# 35                                             B1 L14   5166       000212
# 36                                             B1 L15   5585       000213
# 37                                             B1 L16   5730       000214
# 38                                             B1 L17   5243       000215
# 39                                             B1 L18   5700       000216
# 40                                             B1 L19   4615       000217
# 41                                             B1 L20  2020R       000218
# 42                                             B1 L21  2018R       000219
# 43                                             B1 L22   3495       000220
# 44                                      B1 L23 TO L25   5188       000222
# 45                                             B1 L26  2014R       000224
# 46                                             B1 L27  2019R       000225
# 47                                      B2 N 150FT L1  2019R       000226
# 48                                      B2 S 100FT L1   4586       000228
# 49  B2 L2, L3 & S 50FT OF N 200FT L1; ALSO BRUNE, ...  2020R       000231
#
#    councilDistrict      id isPrimary                            status  \
# 0                7  65001         Y  {'value': 'A', 'text': 'Active'}
# 1                5  65706         Y  {'value': 'A', 'text': 'Active'}
# 2                5  65707         Y  {'value': 'A', 'text': 'Active'}
# 3                5  65801         Y  {'value': 'A', 'text': 'Active'}
# 4                5  65901         Y  {'value': 'A', 'text': 'Active'}
# 5                5  66000         Y  {'value': 'A', 'text': 'Active'}
# 6                5  66100         Y  {'value': 'A', 'text': 'Active'}
# 7                5  66102         Y  {'value': 'A', 'text': 'Active'}
# 8                5  66200         Y  {'value': 'A', 'text': 'Active'}
# 9                5  66300         Y  {'value': 'A', 'text': 'Active'}
# 10               5  66301         Y  {'value': 'A', 'text': 'Active'}
# 11                  90000         Y  {'value': 'A', 'text': 'Active'}
# 12               1  000100         Y  {'value': 'A', 'text': 'Active'}
# 13               1  000101         Y  {'value': 'A', 'text': 'Active'}
# 14               1  000105         Y  {'value': 'A', 'text': 'Active'}
# 15               1  000106         Y  {'value': 'A', 'text': 'Active'}
# 16               1  000108         Y  {'value': 'A', 'text': 'Active'}
# 17               1  000109         Y  {'value': 'A', 'text': 'Active'}
# 18               1  000110         Y  {'value': 'A', 'text': 'Active'}
# 19               1  000112         Y  {'value': 'A', 'text': 'Active'}
# 20               1  000113         Y  {'value': 'A', 'text': 'Active'}
# 21               1  000114         Y  {'value': 'A', 'text': 'Active'}
# 22               1  000115         Y  {'value': 'A', 'text': 'Active'}
# 23               1  000200         Y  {'value': 'A', 'text': 'Active'}
# 24               1  000201         Y  {'value': 'A', 'text': 'Active'}
# 25               1  000202         Y  {'value': 'A', 'text': 'Active'}
# 26               1  000203         Y  {'value': 'A', 'text': 'Active'}
# 27               1  000204         Y  {'value': 'A', 'text': 'Active'}
# 28               1  000205         Y  {'value': 'A', 'text': 'Active'}
# 29               1  000206         Y  {'value': 'A', 'text': 'Active'}
# 30               1  000207         Y  {'value': 'A', 'text': 'Active'}
# 31               1  000208         Y  {'value': 'A', 'text': 'Active'}
# 32               1  000209         Y  {'value': 'A', 'text': 'Active'}
# 33               1  000210         Y  {'value': 'A', 'text': 'Active'}
# 34               1  000211         Y  {'value': 'A', 'text': 'Active'}
# 35               1  000212         Y  {'value': 'A', 'text': 'Active'}
# 36               1  000213         Y  {'value': 'A', 'text': 'Active'}
# 37               1  000214         Y  {'value': 'A', 'text': 'Active'}
# 38               1  000215         Y  {'value': 'A', 'text': 'Active'}
# 39               1  000216         Y  {'value': 'A', 'text': 'Active'}
# 40               1  000217         Y  {'value': 'A', 'text': 'Active'}
# 41               1  000218         Y  {'value': 'A', 'text': 'Active'}
# 42               1  000219         Y  {'value': 'A', 'text': 'Active'}
# 43               1  000220         Y  {'value': 'A', 'text': 'Active'}
# 44               1  000222         Y  {'value': 'A', 'text': 'Active'}
# 45               1  000224         Y  {'value': 'A', 'text': 'Active'}
# 46               1  000225         Y  {'value': 'A', 'text': 'Active'}
# 47               1  000226         Y  {'value': 'A', 'text': 'Active'}
# 48               1  000228         Y  {'value': 'A', 'text': 'Active'}
# 49               1  000231         Y  {'value': 'A', 'text': 'Active'}
#
#     landValue  improvedValue
# 0         NaN            NaN
# 1         NaN            NaN
# 2         NaN            NaN
# 3     21520.0            NaN
# 4         NaN            NaN
# 5     89730.0        23170.0
# 6         NaN            NaN
# 7         NaN            NaN
# 8      1000.0            NaN
# 9      1080.0            NaN
# 10        NaN            NaN
# 11        NaN            NaN
# 12    11450.0        80130.0
# 13    11810.0       103250.0
# 14    27620.0        74290.0
# 15    15020.0            0.0
# 16     3210.0            0.0
# 17     3650.0        67730.0
# 18     4290.0            0.0
# 19    18650.0        85250.0
# 20    15190.0       147710.0
# 21    16880.0       165020.0
# 22      130.0            0.0
# 23    25110.0       884010.0
# 24    17080.0        55220.0
# 25    17040.0        21560.0
# 26    41470.0        41510.0
# 27    12340.0            0.0
# 28    14230.0        66840.0
# 29   109900.0       160290.0
# 30    17080.0        66480.0
# 31    16960.0        71740.0
# 32    17080.0       108590.0
# 33    17080.0       134020.0
# 34    17040.0        61000.0
# 35    17080.0            0.0
# 36    17020.0        17080.0
# 37    16910.0            0.0
# 38     3360.0            0.0
# 39    16920.0        45680.0
# 40    16950.0        85590.0
# 41    17080.0        93090.0
# 42     3420.0            0.0
# 43    17080.0        73140.0
# 44    19570.0        76300.0
# 45    17060.0        30050.0
# 46    17050.0        64350.0
# 47    41560.0        44440.0
# 48    14240.0        35760.0
# 49   178080.0       213820.0

# %%
#To iterate over api calls we need to increase offset by 1000 so we get unique records

#start offset at 0
offset = 0

#offset_stop is the number of rows of data that will be called
offset_stop = 2000

parameters = {
        'grant_type': 'password', #Security type
        'client_id': '637695663724668394', #Application ID
        'client_secret': '342b6fc9f76f49db993230d55511097f', #Application Secret ID
        'username': 'NREBOVICH', #My username
        'password': '#Test12345', #My password
        'scope': 'parcels', #Scope of API Call
        'agency_name': 'UG', #Accela Agency Name
        'environment': 'TEST',
        'limit': '1000'
    }

    #Set header to the token that was called above
token_header = {
            'Authorization': token
        }


    #Call api for data based on parameters and token header
response = requests.get(url,params = parameters, headers = token_header).json()
    
print('API Status')
print(response['status'])
    
    #Convert API response data into pandas dataframe
df = pd.DataFrame(response["result"])
    
    
    #Loop over calls until there is no more data (hasmore == False)
    #Each loop calls the next 1000 rows of data
while response['page']['hasmore'] == True:
#offset should equal limit in parameters
    offset += 1000
#convert offset to string so it can be used in parameters below
    offset_str = str(offset)
    parameters = {
            'grant_type': 'password', #Security type
            'client_id': '637695663724668394', #Application ID
            'client_secret': '342b6fc9f76f49db993230d55511097f', #Application Secret ID
            'username': 'NREBOVICH', #My username
            'password': '#Test12345', #My password
            'scope': 'parcels', #Scope of API Call
            'agency_name': 'UG', #Accela Agency Name
            'environment': 'TEST', #environment
            'offset': offset_str, #offset increases by 1000 each loop
            'limit': '1000' #maximum number of rows returned for each call
        }

    response_2 = requests.get(url,params = parameters, headers = token_header).json() #API call for each loop
    print(int((offset/offset_stop) * 100), "%") #Gives percent of rows called out of total
    df2 = pd.DataFrame(response_2["result"]) #convert call data into pandas dataframe
    df = df.append(df2) #append new row data into original call data in pandas dataframe
    if offset == offset_stop: #stops loop when offset equals total rows the you want to call in offset_stop
        break

print('API Status')
print(response_2['status'])
# Out:
# API Status
# 200
# 50 %
# 100 %
# API Status
# 200

# %%
#To iterate over api calls we need to increase offset by 1000 so we get unique records

def call_api(offset_stop): #offset_stop is the number of rows of data that will be called
#start offset at 0
    offset = 0

    parameters = {
        'grant_type': 'password', #Security type
        'client_id': '637695663724668394', #Application ID
        'client_secret': '342b6fc9f76f49db993230d55511097f', #Application Secret ID
        'username': 'NREBOVICH', #My username
        'password': '#Test12345', #My password
        'scope': 'get_records', #Scope of API Call
        'agency_name': 'UG', #Accela Agency Name
        'environment': 'TEST',
        'limit': '1000'
        }

    #Set header to the token that was called above
    token_header = {
            'Authorization': token
            }


    #Call api for data based on parameters and token header
    response = requests.get(base_url,params = parameters, headers = token_header).json()

    
    #Convert API response data into pandas dataframe
    df = pd.DataFrame(response["result"])
    
    
    #Loop over calls until there is no more data (hasmore == False)
    #Each loop calls the next 1000 rows of data
    while response['page']['hasmore'] == True:
    #offset should equal limit in parameters
        offset += 1000
    #convert offset to string so it can be used in parameters below
        offset_str = str(offset)
        parameters = {
            'grant_type': 'password', #Security type
            'client_id': '637695663724668394', #Application ID
            'client_secret': '342b6fc9f76f49db993230d55511097f', #Application Secret ID
            'username': 'NREBOVICH', #My username
            'password': '#Test12345', #My password
            'scope': 'get_records', #Scope of API Call
            'agency_name': 'UG', #Accela Agency Name
            'environment': 'TEST', #environment
            'offset': offset_str, #offset increases by 1000 each loop
            'limit': '1000' #maximum number of rows returned for each call
            }

        response_2 = requests.get(base_url,params = parameters, headers = token_header).json() #API call for each loop
        print(int((offset/offset_stop) * 100), "%") #Gives percent of rows called out of total
        df2 = pd.DataFrame(response_2["result"]) #convert call data into pandas dataframe
        df = df.append(df2) #append new row data into original call data in pandas dataframe
        if offset == offset_stop: #stops loop when offset equals total rows the you want to call in offset_stop
            print('\n')
            print('API Status')
            print(response_2['status'])
            break

# %%
call_api(2000)
# Out:
# 50 %
# 100 %
#
#
# API Status
# 200

# %%
for col in df.columns:
    print(col)
# Out:
# id
# type
# module
# recordClass
# undistributedCost
# status
# updateDate
# reportedDate
# createdBy
# initiatedProduct
# serviceProviderCode
# customId
# statusDate
# trackingId
# jobValue
# openedDate
# totalJobCost
# value
# totalFee
# totalPay
# balance
# booking
# infraction
# misdemeanor
# offenseWitnessed
# defendantSignature
# publicOwned
# name
# createdByCloning
# actualProductionUnit
# estimatedProductionUnit
# reportedChannel
# description
# numberOfBuildings
# housingUnits
# shortNotes
# scheduledDate
# assignedUser
# assignedToDepartment
# inspectorDepartment
# inspectorName
# closedDate
# closedByDepartment
# closedByUser
# completedDate
# completedByUser
# completedByDepartment
# assignedDate
# constructionType

# %%
df_enforce = df[df['module'] == 'Enforce']

# %%
df['updateDate']= pd.to_datetime(df['updateDate'])
df['reportedDate']= pd.to_datetime(df['reportedDate'])
df['statusDate']= pd.to_datetime(df['statusDate'])
df['scheduledDate']= pd.to_datetime(df['scheduledDate'])
df['closedDate']= pd.to_datetime(df['closedDate'])
df['completedDate']= pd.to_datetime(df['completedDate'])
df['assignedDate']= pd.to_datetime(df['assignedDate'])

# %%
data_nulls = pd.isnull(df_enforce).sum()/len(df_enforce['id'])
data_nulls.sort_values(ascending=False)
# Out:
# constructionType          1.00
# shortNotes                1.00
# completedDate             1.00
# completedByDepartment     1.00
# completedByUser           1.00
# assignedDate              1.00
# createdByCloning          1.00
# closedByUser              0.96
# numberOfBuildings         0.81
# housingUnits              0.81
# closedByDepartment        0.80
# closedDate                0.80
# name                      0.65
# assignedUser              0.43
# assignedToDepartment      0.42
# estimatedProductionUnit   0.41
# actualProductionUnit      0.41
# inspectorName             0.39
# inspectorDepartment       0.39
# description               0.33
# reportedChannel           0.23
# reportedDate              0.23
# scheduledDate             0.13
# status                    0.01
# recordClass               0.00
# publicOwned               0.00
# id                        0.00
# defendantSignature        0.00
# type                      0.00
# module                    0.00
# undistributedCost         0.00
# updateDate                0.00
# createdBy                 0.00
# initiatedProduct          0.00
# serviceProviderCode       0.00
# customId                  0.00
# statusDate                0.00
# trackingId                0.00
# jobValue                  0.00
# openedDate                0.00
# totalJobCost              0.00
# value                     0.00
# totalFee                  0.00
# totalPay                  0.00
# balance                   0.00
# booking                   0.00
# infraction                0.00
# misdemeanor               0.00
# offenseWitnessed          0.00
# dtype: float64

# %%
example = df_enforce.iloc[0:5]
example

ax = plt.gca()


formatter = mdates.DateFormatter("%Y-%m-%d")

ax.xaxis.set_major_formatter(formatter)

locator = mdates.DayLocator()

ax.xaxis.set_major_locator(locator)

ax.plot(example['reportedDate'], example['totalPay'])
# Out:
# Locator attempting to generate 4018 ticks ([10775.0, ..., 14792.0]), which exceeds Locator.MAXTICKS (1000).
# Error in callback <function flush_figures at 0x0000021E78A6DF78> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     429         self.gridline.set(
#     430             xdata=[0, 0], ydata=[0, 1],
# --> 431             transform=self.axes.get_xaxis_transform(which="grid"),
#     432         )
#     433         # the y loc is 3 points below the min of y axis
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1086     def set(self, **kwargs):
#    1087         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1088         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1089         move_color_to_start = False
#    1090         if "color" in kwargs:
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\cbook\__init__.py in normalize_kwargs(kw, alias_mapping, required, forbidden, allowed)
#    1730
#    1731     to_canonical = {alias: canonical
# -> 1732                     for canonical, alias_list in alias_mapping.items()
#    1733                     for alias in alias_list}
#    1734     canonical_to_seen = {}
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\cbook\__init__.py in <dictcomp>(.0)
#    1731     to_canonical = {alias: canonical
#    1732                     for canonical, alias_list in alias_mapping.items()
# -> 1733                     for alias in alias_list}
#    1734     canonical_to_seen = {}
#    1735     ret = {}  # output dictionary
#
# KeyboardInterrupt:

# %%
example['statusDate']
#example['createdBy']
# Out:
# 1     2021-10-11 13:38:22
# 22    2021-08-12 14:50:24
# 23    2021-08-12 14:45:37
# 24    2021-08-12 00:00:00
# 25    2021-08-12 12:39:46
# Name: statusDate, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

date_time = ["2021-01-01", "2021-01-02", "2021-01-03"]
date_time = pd.to_datetime(date_time)
data = [1, 2, 3, 5, 8]

DF = pd.DataFrame()
DF['value'] = data
DF = DF.set_index(example['statusDate'])
plt.plot(example['statusDate'], data)
plt.gcf().autofmt_xdate()
plt.show()

# %%
plt.plot(df_enforce['totalFee'], df_enforce['totalPay'])

# %%
data_nulls = pd.isnull(df).sum()/len(df['id'])
data_nulls.sort_values(ascending=False)
# Out:
# completedDate              0.999905
# assignedDate               0.999714
# constructionType           0.997667
# assignedUser               0.969048
# assignedToDepartment       0.969000
# completedByUser            0.941857
# completedByDepartment      0.941714
# createdByCloning           0.940095
# shortNotes                 0.920810
# inspectorName              0.919286
# inspectorDepartment        0.918905
# actualProductionUnit       0.868714
# estimatedProductionUnit    0.868714
# scheduledDate              0.862857
# closedByUser               0.859810
# closedDate                 0.785667
# closedByDepartment         0.785667
# name                       0.305714
# housingUnits               0.286810
# numberOfBuildings          0.286810
# description                0.239476
# reportedChannel            0.125952
# reportedDate               0.113095
# recordClass                0.034810
# status                     0.013238
# createdBy                  0.000762
# initiatedProduct           0.000048
# id                         0.000000
# publicOwned                0.000000
# openedDate                 0.000000
# module                     0.000000
# undistributedCost          0.000000
# updateDate                 0.000000
# serviceProviderCode        0.000000
# customId                   0.000000
# statusDate                 0.000000
# trackingId                 0.000000
# jobValue                   0.000000
# totalJobCost               0.000000
# defendantSignature         0.000000
# value                      0.000000
# totalFee                   0.000000
# totalPay                   0.000000
# balance                    0.000000
# booking                    0.000000
# infraction                 0.000000
# misdemeanor                0.000000
# type                       0.000000
# offenseWitnessed           0.000000
# dtype: float64

# %%
df.dtypes

# %%
df['updateDate']= pd.to_datetime(df['updateDate'])
df['reportedDate']= pd.to_datetime(df['reportedDate'])
df['statusDate']= pd.to_datetime(df['statusDate'])
df['scheduledDate']= pd.to_datetime(df['scheduledDate'])
df['closedDate']= pd.to_datetime(df['closedDate'])
df['completedDate']= pd.to_datetime(df['completedDate'])
df['assignedDate']= pd.to_datetime(df['assignedDate'])

# %%
df.dtypes
# Out:
# id                                 object
# type                               object
# module                             object
# recordClass                        object
# undistributedCost                 float64
# status                             object
# updateDate                 datetime64[ns]
# reportedDate               datetime64[ns]
# createdBy                          object
# initiatedProduct                   object
# serviceProviderCode                object
# customId                           object
# statusDate                 datetime64[ns]
# trackingId                          int64
# jobValue                          float64
# openedDate                         object
# totalJobCost                      float64
# value                              object
# totalFee                          float64
# totalPay                          float64
# balance                           float64
# booking                              bool
# infraction                           bool
# misdemeanor                          bool
# offenseWitnessed                     bool
# defendantSignature                   bool
# publicOwned                          bool
# name                               object
# createdByCloning                   object
# actualProductionUnit              float64
# estimatedProductionUnit           float64
# reportedChannel                    object
# description                        object
# numberOfBuildings                 float64
# housingUnits                      float64
# shortNotes                         object
# scheduledDate              datetime64[ns]
# assignedUser                       object
# assignedToDepartment               object
# inspectorDepartment                object
# inspectorName                      object
# closedDate                 datetime64[ns]
# closedByDepartment                 object
# closedByUser                       object
# completedDate              datetime64[ns]
# completedByUser                    object
# completedByDepartment              object
# assignedDate               datetime64[ns]
# constructionType                   object
# dtype: object

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df.describe()
# Out:
#        undistributedCost      trackingId     jobValue  totalJobCost  \
# count           21000.00        21000.00     21000.00      21000.00
# mean                0.00 419049585576.54     36857.15          0.00
# std                 0.00     28987740.42   2232219.11          0.00
# min                 0.00 419000002144.00         0.00          0.00
# 25%                 0.00 419024441118.50         0.00          0.00
# 50%                 0.00 419049404911.00         0.00          0.00
# 75%                 0.00 419074951007.00         0.00          0.00
# max                 0.00 419099994744.00 300000000.00          0.00
#
#         totalFee   totalPay  balance  actualProductionUnit  \
# count   21000.00   21000.00 21000.00               2757.00
# mean      210.70     177.12    33.70                  0.00
# std      9157.23    9148.86   297.56                  0.00
# min         0.00       0.00     0.00                  0.00
# 25%         0.00       0.00     0.00                  0.00
# 50%         0.00       0.00     0.00                  0.00
# 75%        58.88      41.50     0.00                  0.00
# max   1201105.00 1201105.00 30269.00                  0.00
#
#        estimatedProductionUnit  numberOfBuildings  housingUnits
# count                  2757.00           14977.00      14977.00
# mean                      0.00               0.08          0.20
# std                       0.00               0.30         14.73
# min                       0.00               0.00          0.00
# 25%                       0.00               0.00          0.00
# 50%                       0.00               0.00          0.00
# 75%                       0.00               0.00          0.00
# max                       0.00              15.00       1800.00

# %%
import matplotlib.dates as mdates

# %%
df.head()
# Out:
#                      id                                               type  \
# 0  UG-21CAP-00000-0008V  {'module': 'PublicWorks', 'value': 'PublicWork...
# 1  UG-21299-00000-00008  {'module': 'Enforce', 'value': 'Enforce/Code A...
# 2  UG-21CAP-00000-0008S  {'module': 'PublicWorks', 'value': 'PublicWork...
# 3  UG-21CAP-00000-0008T  {'module': 'PublicWorks', 'value': 'PublicWork...
# 4  UG-21CAP-00000-0008U  {'module': 'PublicWorks', 'value': 'PublicWork...
#
#         module recordClass  undistributedCost  \
# 0  PublicWorks    COMPLETE                0.0
# 1      Enforce    COMPLETE                0.0
# 2  PublicWorks         NaN                0.0
# 3  PublicWorks         NaN                0.0
# 4  PublicWorks         NaN                0.0
#
#                               status          updateDate        reportedDate  \
# 0  {'value': 'Open', 'text': 'Open'} 2021-10-11 08:40:31 2021-10-11 08:33:54
# 1  {'value': 'Open', 'text': 'Open'} 2021-10-11 13:38:22                 NaT
# 2  {'value': 'Open', 'text': 'Open'} 2021-09-30 16:59:55 2021-09-30 16:59:55
# 3  {'value': 'Open', 'text': 'Open'} 2021-09-30 16:59:56 2021-09-30 16:59:56
# 4  {'value': 'Open', 'text': 'Open'} 2021-09-30 16:59:56 2021-09-30 16:59:57
#
#         createdBy initiatedProduct  ... inspectorDepartment inspectorName  \
# 0  PUBLICUSER2042              ACA  ...                 NaN           NaN
# 1        JRAMIREZ             EMSE  ...                 NaN           NaN
# 2        JRAMIREZ            AV360  ...                 NaN           NaN
# 3        JRAMIREZ            AV360  ...                 NaN           NaN
# 4        JRAMIREZ            AV360  ...                 NaN           NaN
#
#   closedDate  closedByDepartment  closedByUser completedDate  completedByUser  \
# 0        NaT                 NaN           NaN           NaT              NaN
# 1        NaT                 NaN           NaN           NaT              NaN
# 2        NaT                 NaN           NaN           NaT              NaN
# 3        NaT                 NaN           NaN           NaT              NaN
# 4        NaT                 NaN           NaN           NaT              NaN
#
#   completedByDepartment  assignedDate  constructionType
# 0                   NaN           NaT               NaN
# 1                   NaN           NaT               NaN
# 2                   NaN           NaT               NaN
# 3                   NaN           NaT               NaN
# 4                   NaN           NaT               NaN
#
# [5 rows x 49 columns]

# %%
import matplotlib.pyplot as plt

ax.bar(,students)
plt.show()

# %%
df = pd.concat([df.drop(['type'], axis=1), df['type'].apply(pd.Series)], axis=1)
df = pd.concat([df.drop(['status'], axis=1), df['status'].apply(pd.Series)], axis=1)
